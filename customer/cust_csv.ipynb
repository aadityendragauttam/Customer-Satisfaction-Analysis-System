# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\user\Downloads\cust_satisfaction.csv")

# %%
df
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# ...

# %%
df.isna().sum()
# Out:
# Gender                          0
# Customer Type                   0
# Type of Travel                  0
# Class                           0
# satisfaction                    0
# Age                             0
# Flight Distance                 0
# Inflight entertainment          0
# Baggage handling                0
# Cleanliness                     0
# Departure Delay in Minutes      0
# Arrival Delay in Minutes      310
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# Gender                        0
# Customer Type                 0
# Type of Travel                0
# Class                         0
# satisfaction                  0
# Age                           0
# Flight Distance               0
# Inflight entertainment        0
# Baggage handling              0
# Cleanliness                   0
# Departure Delay in Minutes    0
# Arrival Delay in Minutes      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(172)

# %%
df.drop_duplicates(inplace= True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 103422 entries, 0 to 103903
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Gender                      103422 non-null  str
#  1   Customer Type               103422 non-null  str
#  2   Type of Travel              103422 non-null  str
#  3   Class                       103422 non-null  str
#  4   satisfaction                103422 non-null  str
#  5   Age                         103422 non-null  int64
#  6   Flight Distance             103422 non-null  int64
#  7   Inflight entertainment      103422 non-null  int64
#  8   Baggage handling            103422 non-null  int64
#  9   Cleanliness                 103422 non-null  int64
#  10  Departure Delay in Minutes  103422 non-null  int64
#  11  Arrival Delay in Minutes    103422 non-null  float64
# dtypes: float64(1), int64(6), str(5)
# memory usage: 10.3 MB

# %%
df
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# ...

# %%
gender_dict = {
    'Male':0,
    'Female':1
}

# %%
df['Gender']=df['Gender'].map(gender_dict)

# %%
df['Gender']
# Out:
# 0         0
# 1         0
# 2         1
# 3         1
# 4         0
#          ..
# 103899    1
# 103900    0
# 103901    0
# 103902    1
# 103903    0
# Name: Gender, Length: 103422, dtype: int64

# %%
df
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0            0     Loyal Customer  Personal Travel  Eco Plus
# 1            0  disloyal Customer  Business travel  Business
# 2            1     Loyal Customer  Business travel  Business
# 3            1     Loyal Customer  Business travel  Business
# 4            0     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899       1  disloyal Customer  Business travel       Eco
# 103900       0     Loyal Customer  Business travel  Business
# 103901       0  disloyal Customer  Business travel  Business
# 103902       1  disloyal Customer  Business travel       Eco
# 103903       0     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# ...

# %%
df['Customer Type'].unique()
# Out:
# <StringArray>
# ['Loyal Customer', 'disloyal Customer']
# Length: 2, dtype: str

# %%
cust_type_dict = {
    'Loyal Customer':0,'disloyal Customer':1
}

# %%
df['Customer Type'] = df['Customer Type'].map(cust_type_dict)

# %%
df
# Out:
#         Gender  Customer Type   Type of Travel     Class  \
# 0            0              0  Personal Travel  Eco Plus
# 1            0              1  Business travel  Business
# 2            1              0  Business travel  Business
# 3            1              0  Business travel  Business
# 4            0              0  Business travel  Business
# ...        ...            ...              ...       ...
# 103899       1              1  Business travel       Eco
# 103900       0              0  Business travel  Business
# 103901       0              1  Business travel  Business
# 103902       1              1  Business travel       Eco
# 103903       0              0  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# 1       neutral or dissatisfied   25              235                       1
# ...

# %%
df['Type of Travel'].unique()
# Out:
# <StringArray>
# ['Personal Travel', 'Business travel']
# Length: 2, dtype: str

# %%
travel_type_dict = {
    'Personal Travel':0,'Business travel':1
}

# %%
df['Type of Travel'] = df['Type of Travel'].map(travel_type_dict)

# %%
df
# Out:
#         Gender  Customer Type  Type of Travel     Class  \
# 0            0              0               0  Eco Plus
# 1            0              1               1  Business
# 2            1              0               1  Business
# 3            1              0               1  Business
# 4            0              0               1  Business
# ...        ...            ...             ...       ...
# 103899       1              1               1       Eco
# 103900       0              0               1  Business
# 103901       0              1               1  Business
# 103902       1              1               1       Eco
# 103903       0              0               1  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# 1       neutral or dissatisfied   25              235                       1
# ...

# %%
df['Class'].unique()
# Out:
# <StringArray>
# ['Eco Plus', 'Business', 'Eco']
# Length: 3, dtype: str

# %%
class_dict =  {
    'Eco Plus':0, 'Business':1, 'Eco':2
}

# %%
df['Class'] = df['Class'].map(class_dict)

# %%
df
# Out:
#         Gender  Customer Type  Type of Travel  Class             satisfaction  \
# 0            0              0               0      0  neutral or dissatisfied
# 1            0              1               1      1  neutral or dissatisfied
# 2            1              0               1      1                satisfied
# 3            1              0               1      1  neutral or dissatisfied
# 4            0              0               1      1                satisfied
# ...        ...            ...             ...    ...                      ...
# 103899       1              1               1      2  neutral or dissatisfied
# 103900       0              0               1      1                satisfied
# 103901       0              1               1      1  neutral or dissatisfied
# 103902       1              1               1      2  neutral or dissatisfied
# 103903       0              0               1      1  neutral or dissatisfied
#
# ...

# %%
df['satisfaction'].unique()
# Out:
# <StringArray>
# ['neutral or dissatisfied', 'satisfied']
# Length: 2, dtype: str

# %%
satis_dict = {
    'neutral or dissatisfied':0, 'satisfied':1
}

# %%
df['satisfaction'] = df['satisfaction'].map(satis_dict)

# %%
df
# Out:
#         Gender  Customer Type  Type of Travel  Class  satisfaction  Age  \
# 0            0              0               0      0             0   13
# 1            0              1               1      1             0   25
# 2            1              0               1      1             1   26
# 3            1              0               1      1             0   25
# 4            0              0               1      1             1   61
# ...        ...            ...             ...    ...           ...  ...
# 103899       1              1               1      2             0   23
# 103900       0              0               1      1             1   49
# 103901       0              1               1      1             0   30
# 103902       1              1               1      2             0   22
# 103903       0              0               1      1             0   27
#
#         Flight Distance  Inflight entertainment  Baggage handling  \
# ...

# %%
sns.histplot(df['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(df['Flight Distance'])
# Out:
# <Axes: xlabel='Flight Distance', ylabel='Count'>

# %%
sns.histplot(df['Departure Delay in Minutes'], bins=30)
# Out:
# <Axes: xlabel='Departure Delay in Minutes', ylabel='Count'>

# %%
sns.histplot(df['Arrival Delay in Minutes'])
# Out:
# <Axes: xlabel='Arrival Delay in Minutes', ylabel='Count'>

# %%
sns.scatterplot(x='Flight Distance',y='Arrival Delay in Minutes',hue='Customer Type',data=df)
plt.show()

# %%
sns.kdeplot(data=df,x='Flight Distance',hue='Customer Type')
plt.show()

# %%
sns.histplot(data=df,x='Flight Distance',hue='Customer Type')
plt.show()

# %%
sns.relplot(data=df,x='Flight Distance',y='Arrival Delay in Minutes',hue='Customer Type')

# %%
sns.relplot(data=df,x='Age',y='Flight Distance',hue='Customer Type')

# %%
df
# Out:
#         Gender  Customer Type  Type of Travel  Class  satisfaction  Age  \
# 0            0              0               0      0             0   13
# 1            0              1               1      1             0   25
# 2            1              0               1      1             1   26
# 3            1              0               1      1             0   25
# 4            0              0               1      1             1   61
# ...        ...            ...             ...    ...           ...  ...
# 103899       1              1               1      2             0   23
# 103900       0              0               1      1             1   49
# 103901       0              1               1      1             0   30
# 103902       1              1               1      2             0   22
# 103903       0              0               1      1             0   27
#
#         Flight Distance  Inflight entertainment  Baggage handling  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 103422 entries, 0 to 103903
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Gender                      103422 non-null  int64
#  1   Customer Type               103422 non-null  int64
#  2   Type of Travel              103422 non-null  int64
#  3   Class                       103422 non-null  int64
#  4   satisfaction                103422 non-null  int64
#  5   Age                         103422 non-null  int64
#  6   Flight Distance             103422 non-null  int64
#  7   Inflight entertainment      103422 non-null  int64
#  8   Baggage handling            103422 non-null  int64
#  9   Cleanliness                 103422 non-null  int64
#  10  Departure Delay in Minutes  103422 non-null  int64
#  11  Arrival Delay in Minutes    103422 non-null  float64
# dtypes: float64(1), int64(11)
# memory usage: 10.3 MB

# %%
df.drop_duplicates()
# Out:
#         Gender  Customer Type  Type of Travel  Class  satisfaction  Age  \
# 0            0              0               0      0             0   13
# 1            0              1               1      1             0   25
# 2            1              0               1      1             1   26
# 3            1              0               1      1             0   25
# 4            0              0               1      1             1   61
# ...        ...            ...             ...    ...           ...  ...
# 103899       1              1               1      2             0   23
# 103900       0              0               1      1             1   49
# 103901       0              1               1      1             0   30
# 103902       1              1               1      2             0   22
# 103903       0              0               1      1             0   27
#
#         Flight Distance  Inflight entertainment  Baggage handling  \
# ...

# %%
df.drop('Arrival Delay in Minutes',axis=1,inplace=True)

# %%
df.to_csv('cleaned_cust.csv')
